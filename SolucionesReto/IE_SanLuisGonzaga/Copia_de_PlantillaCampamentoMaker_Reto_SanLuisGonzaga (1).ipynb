# %% [markdown]
# <figure>
#     <img src="https://i.imgur.com/x33dUXh.png" width=1400>
# </figure>

# %% [markdown]
# <h1 align="center">Campamento Maker 2023</h1>
# <h1 align="center">Plantilla para la solución del reto</h1>
# <p align="center">por</p>
# <h3 align="center">Equipo Formación Campamento Maker</h3>
#
# <h3 align="center">Propuesta Campamento Maker: San Luis Gonzaga </h3>
# <h1 align='center' style='color: #660066; font-weight: bold;'>ROBOTICA 3.0</h1>
#
#
#
#
# El reto consiste en proporcionar una visión de la distribución real y la distribución ideal de las personas en la plataforma del metro en la estación San Antonio. Para ello, se superpondrá una imagen creada por los estudiantes sobre una maqueta. En este documento se proporciona una plantilla que muestra cómo subir una imegen de referencia con las dimensiones adecuadas para ser proyectada sobre la maqueta.

# %% [markdown]
# ## Importación de librerias

# %%
import numpy as np
import matplotlib.pyplot as plt
import requests

from IPython.display import display

# %matplotlib inline

# %% [markdown]
# ## Conexión con Google Drive y Carga de la imagen con resolución estandar
#
# Antes de ejecutar las siguientes lineas de código, asegurese de haber subirdo la carpeta "[Campamento Maker](https://drive.google.com/uc?id=1QUhwfTpSbnzFbkGP3KAq2RZ5okwQ8w3W&export=download)" a su Google Drive. El siguiente video es un paso a paso de cómo hacerlo luego de que la haya descargado en su computador.
#
# <figure align="center">
#     <img src="https://i.imgur.com/HR9olpO.gif" width=600>
#     <figcaption align="center">El video se puede encontrar en la carpeta provista.</figcaption>
# </figure>

# %%
# Ejecute esta celda para conectarse con Google Drive...
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Crear una figura y un eje
fig, ax = plt.subplots(figsize=(11,7))

# CAMBIE ESTA RUTA SEGÚN LAS INSTRUCCIONES DEL VIDEO
direccion = '/content/drive/MyDrive/Campamento_Maker/Campamento_Maker/'

# Agregar la imagen de fondo
img = plt.imread(direccion + 'background_logo.jpeg')  # Reemplaza 'background.jpg' por 'crop_image.jpeg' para tener una referencia
ax.imshow(img, extent=[0, 1280/214, 0, 720/214], alpha=1)  # **No modificar** Define los límites de la imagen

# %% [markdown]
# ____________________________________
# # Inicio de la solución
#
# Aqui agregarán el código donde realizarán la distribución de las personas sobre la plataforma.

# %%
ax.text(4,3.2, "Robotica 3.0") # Coloque el nombre de su institucion

# Recuerde que para agregar elementos a la grafica lo debe hacer sobre la variable ax asi:
#ax.scatter(3,3) # Aqui agregamos un punto en la posicion 3,3


###################################################################################
##### # Escriba su código de Python aquí... #######################################
###################################################################################

from matplotlib.patches import Rectangle

rect = Rectangle((0.09,1.7), 5.78, 0.18, linewidth=2, edgecolor="black", fill=False)

ax.add_patch(rect)

ax.vlines(x=1, ymin=1.7, ymax=1.88, color = "black")
ax.vlines(x=2, ymin=1.7, ymax=1.88, color = "k")
ax.vlines(x=3, ymin=1.7, ymax=1.88, color = "k")
ax.vlines(x=4, ymin=1.7, ymax=1.88, color = "black")
ax.vlines(x=5, ymin=1.7, ymax=1.88, color = "k")

import numpy as np
# creamos una lista convencional de python
lista1 = [80, 88, 184, 170, 120, 88]
# creamos un array de numpy con la misma informacion
array1 = np.array([80, 88, 184, 170, 120, 88])

print("Esta es la lista", lista1)
print("Este es el arreglo", array1)

lista2 = [1, 2, 3, 4, 5, 6]
# creamos un array de numpy con la misma informacion
array2 = np.array([1, 2, 3, 4, 5, 6])

print("Esta es la lista", lista2)
print("Este es el arreglo", array2)

a = 0.13
b = 0.96

x_cajon1 = a + (b-a) * np.random.rand(lista1[0])

a = 1.7
b = 1.85
y_cajon1 = a + (b-a) * np.random.rand(lista1[0])

a = 1.08
b = 1.96
x_cajon2 = a + (b-a) * (np.random.rand(lista1[1]))
a = 1.7
b = 1.85
y_cajon2 = a + (b-a) * np.random.rand(lista1[1])

a = 2
b = 2.96
x_cajon3 = a + (b-a) * (np.random.rand(lista1[2]))
a = 1.7
b = 1.85
y_cajon3 = a + (b-a) * np.random.rand(lista1[2])

a = 3
b = 3.96
x_cajon4 = a + (b-a) * (np.random.rand(lista1[3]))
a = 1.7
b = 1.85
y_cajon4 = a + (b-a) * np.random.rand(lista1[3])


a = 4
b = 4.96
x_cajon5 = a + (b-a) * (np.random.rand(lista1[4]))
a = 1.7
b = 1.85
y_cajon5 = a + (b-a) * np.random.rand(lista1[4])

a = 5
b = 5.8
x_cajon6 = a + (b-a) * (np.random.rand(lista1[5]))
a = 1.7
b = 1.85
y_cajon6 = a + (b-a) * np.random.rand(lista1[5])

#se gráfican los puntos
ax.plot(x_cajon1, y_cajon1, 'o', color="red", markersize=2)
ax.plot(x_cajon2, y_cajon2, 'o', color="blue", markersize=2)
ax.plot(x_cajon3, y_cajon3, 'o', color="aqua", markersize=2)
ax.plot(x_cajon4, y_cajon4, 'o', color="green", markersize=2)
ax.plot(x_cajon5, y_cajon5, 'o', color="pink", markersize=2)
ax.plot(x_cajon6, y_cajon6, 'o', color="purple", markersize=2)

ax.text(x = 0.4 , y = 1.5, s = "Sector 1")
ax.text(x = 1.4 , y = 1.5, s = "Sector 2")
ax.text(x = 2.4 , y = 1.5, s = "Sector 3")
ax.text(x = 3.4 , y = 1.5, s = "Sector 4")
ax.text(x = 4.4 , y = 1.5, s = "Sector 5")
ax.text(x = 5.4 , y = 1.5, s = "Sector 6")

ax.text(x = 0.3 , y = 1.3, s = "80 personas ")
ax.text(x = 1.3 , y = 1.3, s = "88 personas")
ax.text(x = 2.3 , y = 1.3, s = "184 personas")
ax.text(x = 3.3 , y = 1.3, s = "170 personas")
ax.text(x = 4.3 , y = 1.3, s = "120 personas")
ax.text(x = 5.3 , y = 1.3, s = "88 personas")

###################################################################################
###################################################################################
###################################################################################

# Para mostrar su avance utilice la siguiente instruccion
display(fig)
# Out:
# Esta es la lista [80, 88, 184, 170, 120, 88]
# Este es el arreglo [ 80  88 184 170 120  88]
# Esta es la lista [1, 2, 3, 4, 5, 6]
# Este es el arreglo [1 2 3 4 5 6]

# %% [markdown]
# ## Preparación de la imagen a proyectar

# %%
ax.axis('off')

# Display the plot
display(fig)

# %% [markdown]
# # Guardar Imagen

# %%
# Aqui se guarda una imagen con la solucion en la carpeta del proyecto
fig.savefig(direccion + 'my_plot.png', dpi=600, bbox_inches='tight')

# %% [markdown]
# # Enviar a la Pagina Web
#
# Este bloque de codigo se debe ejecutar solo para enviar la solución

# %%
url = 'https://makercamp.onrender.com/subir-imagen' # Reemplaza con la URL de tu servidor
files = {'imagen': open(direccion + 'my_plot.png', 'rb')} # Reemplaza con la ruta de tu imagen

respuesta = requests.post(url, files=files)

print(respuesta.text)
# Out:
# {"imagenURL":"https://makercamp.onrender.com/my_plot.png"}
