# %% [markdown]
# <figure>
#     <img src="https://i.imgur.com/x33dUXh.png" width=1400>
# </figure>

# %% [markdown]
# <h1 align="center">Campamento Maker 2023</h1>
# <h1 align="center">Plantilla para la solución del reto</h1>
# <p align="center">por</p>
# <h3 align="center">Equipo Formación Campamento Maker</h3>
#
#
#
# El reto consiste en proporcionar una visión de la distribución real y la distribución ideal de las personas en la plataforma del metro en la estación San Antonio. Para ello, se superpondrá una imagen creada por los estudiantes sobre una maqueta. En este documento se proporciona una plantilla que muestra cómo subir una imegen de referencia con las dimensiones adecuadas para ser proyectada sobre la maqueta.

# %% [markdown]
# ## Importación de librerias

# %%
import numpy as np
import matplotlib.pyplot as plt
import requests

from IPython.display import display

# %matplotlib inline

# %% [markdown]
# ## Conexión con Google Drive y Carga de la imagen con resolución estandar
#
# Antes de ejecutar las siguientes lineas de código, asegurese de haber subirdo la carpeta "[Campamento Maker](https://drive.google.com/uc?id=1QUhwfTpSbnzFbkGP3KAq2RZ5okwQ8w3W&export=download)" a su Google Drive. El siguiente video es un paso a paso de cómo hacerlo luego de que la haya descargado en su computador.
#
# <figure align="center">
#     <img src="https://i.imgur.com/HR9olpO.gif" width=600>
#     <figcaption align="center">El video se puede encontrar en la carpeta provista.</figcaption>
# </figure>

# %%
# Ejecute esta celda para conectarse con Google Drive...
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Crear una figura y un eje
fig, ax = plt.subplots(figsize=(11,7))

# CAMBIE ESTA RUTA SEGÚN LAS INSTRUCCIONES DEL VIDEO
direccion = '/content/drive/MyDrive/Campamento Maker/Campamento_Maker/Campamento_Maker/'

# Agregar la imagen de fondo
img = plt.imread(direccion + 'background_logo.jpeg')  # Reemplaza 'background.jpg' por 'crop_image.jpeg' para tener una referencia
ax.imshow(img, extent=[0, 1280/214, 0, 720/214], alpha=1)  # **No modificar** Define los límites de la imagen

# %% [markdown]
# ____________________________________
# # Inicio de la solución
#
# Aqui agregarán el código donde realizarán la distribución de las personas sobre la plataforma.

# %%
ax.text(4,3.2, "MAKENEM") # Coloque el nombre de su institucion

# Recuerde que para agregar elementos a la grafica lo debe hacer sobre la variable ax asi:
#ax.scatter(3,3) # Aqui agregamos un punto en la posicion 3,3


###################################################################################
##### # Escriba su código de Python aquí... #######################################
###################################################################################
x = np.linspace(0, 6, 500)
y1 = np.ones(500)*1.5
y2 = np.ones(500)*1.8
ax.plot(x,y1, c="red", linewidth= 2)
ax.plot(x,y2, c="red", linewidth= 2)
x1 = np.ones(50)
x2 = np.ones(50)*2
x3 = np.ones(50)*3
x4 = np.ones(50)*4
x5 = np.ones(50)*5
x6 = np.ones(50)*6
x7 = np.zeros(50)
y3 = np.linspace(1.5,1.8, 50)

# creando lista de puntos

v1_x_f1 = np.random.uniform(0.36,0.44,45)
v1_y_f1 = np.random.uniform(1.5,1.8,45)

v1_x_f2 = np.random.uniform(0.76,0.84,45)
v1_y_f2 = np.random.uniform(1.5,1.8,45)


ax.plot(v1_x_f1, v1_y_f1,'o', c = 'k', markersize = 0.5)
ax.plot(v1_x_f2, v1_y_f2,'o', c = 'k', markersize = 0.5)

v2_x_f1 = np.random.uniform(1.36,1.44,45)
v2_y_f1 = np.random.uniform(1.5,1.8,45)

v2_x_f2 = np.random.uniform(1.76,1.84,45)
v2_y_f2 = np.random.uniform(1.5,1.8,45)


ax.plot(v2_x_f1, v2_y_f1,'o', c = 'k', markersize = 0.5, label = 'Personas')
ax.plot(v2_x_f2, v2_y_f2,'o', c = 'k', markersize = 0.5)

v3_x_f1 = np.random.uniform(2.36,2.44,45)
v3_y_f1 = np.random.uniform(1.5,1.8,45)

v3_x_f2 = np.random.uniform(2.76,2.84,45)
v3_y_f2 = np.random.uniform(1.5,1.8,45)


ax.plot(v3_x_f1, v3_y_f1,'o', c = 'k', markersize = 0.5)
ax.plot(v3_x_f2, v3_y_f2,'o', c = 'k', markersize = 0.5)

v4_x_f1 = np.random.uniform(3.36,3.44,45)
v4_y_f1 = np.random.uniform(1.5,1.8,45)

v4_x_f2 = np.random.uniform(3.76,3.84,45)
v4_y_f2 = np.random.uniform(1.5,1.8,45)


ax.plot(v4_x_f1, v4_y_f1,'o', c = 'k', markersize = 0.5)
ax.plot(v4_x_f2, v4_y_f2,'o', c = 'k', markersize = 0.5)

v5_x_f1 = np.random.uniform(4.36,4.44,45)
v5_y_f1 = np.random.uniform(1.5,1.8,45)

v5_x_f2 = np.random.uniform(4.76,4.84,45)
v5_y_f2 = np.random.uniform(1.5,1.8,45)


ax.plot(v5_x_f1, v5_y_f1,'o', c = 'k', markersize = 0.5)
ax.plot(v5_x_f2, v5_y_f2,'o', c = 'k', markersize = 0.5)

v6_x_f1 = np.random.uniform(5.36,5.44,45)
v6_y_f1 = np.random.uniform(1.5,1.8,45)

v6_x_f2 = np.random.uniform(5.76,5.84,45)
v6_y_f2 = np.random.uniform(1.5,1.8,45)


ax.plot(v6_x_f1, v6_y_f1,'o', c = 'k', markersize = 0.5)
ax.plot(v6_x_f2, v6_y_f2,'o', c = 'k', markersize = 0.5)
#ax.scatter(puntos_v1, y4)

ax.plot(x1,y3, c="navy", linewidth= 2)
ax.plot(x2,y3, c="navy", linewidth= 2)
ax.plot(x3,y3, c="navy", linewidth= 2)
ax.plot(x4,y3, c="navy", linewidth= 2)
ax.plot(x5,y3, c="navy", linewidth= 2)
ax.plot(x6,y3, c="red", linewidth= 2)
ax.plot(x7,y3, c="red", linewidth= 2)

ax.text(0.3,1.2,'VAGÓN 1')
ax.text(0.15,1.1,'(90 pasajeros)')

ax.text(1.3,1.2,'VAGÓN 2')
ax.text(1.15,1.1,'(90 pasajeros)')

ax.text(2.3,1.2,'VAGÓN 3')
ax.text(2.15,1.1,'(90 pasajeros)')

ax.text(3.3,1.2,'VAGÓN 4')
ax.text(3.15,1.1,'(90 pasajeros)')

ax.text(4.3,1.2,'VAGÓN 5')
ax.text(4.15,1.1,'(90 pasajeros)')

ax.text(5.3,1.2,'VAGÓN 6')
ax.text(5.15,1.1,'(90 pasajeros)')


ax.arrow(0.2,1.52,0,0.1,width=0.02, color='green', label = 'Puerta de salida')
ax.arrow(0.6,1.52,0,0.1,width=0.02, color='green')

ax.arrow(1.2,1.52,0,0.1,width=0.02, color='green')
ax.arrow(1.6,1.52,0,0.1,width=0.02, color='green')

ax.arrow(2.2,1.52,0,0.1,width=0.02, color='green')
ax.arrow(2.6,1.52,0,0.1,width=0.02, color='green')

ax.arrow(3.2,1.52,0,0.1,width=0.02, color='green')
ax.arrow(3.6,1.52,0,0.1,width=0.02, color='green')

ax.arrow(4.2,1.52,0,0.1,width=0.02, color='green')
ax.arrow(4.6,1.52,0,0.1,width=0.02, color='green')

ax.arrow(5.2,1.52,0,0.1,width=0.02, color='green')
ax.arrow(5.6,1.52,0,0.1,width=0.02, color='green')

ax.text(0.1,2.5,'Acceso y salida intercaladas\nPersonas / vagón: 90\nPersonas / puerta de ingreso: 45')
#ax.text('')

ax.legend(loc =3)




###################################################################################
###################################################################################
###################################################################################

# Para mostrar su avance utilice la siguiente instruccion
display(fig)

# %% [markdown]
# ## Preparación de la imagen a proyectar

# %%
ax.axis('off')

# Display the plot
display(fig)

# %% [markdown]
# # Guardar Imagen

# %%
# Aqui se guarda una imagen con la solucion en la carpeta del proyecto
fig.savefig(direccion + 'my_plot.png', dpi=600, bbox_inches='tight')

# %% [markdown]
# # Enviar a la Pagina Web
#
# Este bloque de codigo se debe ejecutar solo para enviar la solución

# %%
url = 'https://makercamp.onrender.com/subir-imagen' # Reemplaza con la URL de tu servidor
files = {'imagen': open(direccion + 'my_plot.png', 'rb')} # Reemplaza con la ruta de tu imagen

respuesta = requests.post(url, files=files)

print(respuesta.text)
# Out:
# {"imagenURL":"https://makercamp.onrender.com/my_plot.png"}
